# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from plotly import __version__
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

print(__version__) # requires version >= 1.9.0
import cufflinks as cf
cf.go_offline()
sns.set_style('whitegrid')
lll = pd.read_excel('TEST.xlsx')
# Out:
# 5.1.0
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.2.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
oom= opo['StatusValue'].value_counts()[:6]
ll=oom.plot(kind='pie', figsize=(12,9), legend =True , label =False )

# %%
oom= lll['StatusValue'].value_counts()[:7]
oom= lll['VendorValue'].value_counts()
llq=opo['StatusValue'].value_counts()[:6].plot(kind='bar',figsize=(7,8))

# %%
lk=lll['VendorValue'].value_counts()[:40].plot(kind='bar',figsize=(8,9))

# %%
oom.iplot(kind='bar')
# Out:
# <div>                            <div id="1d84127c-815f-4962-9186-6ea5ddc2a7d6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
import plotly.express as px
years=["Withdrawn","Rejected","Completed Interview","Awaiting Interview","Closure","Position Confirmed","Scheduled Interview"]
opo=lll[lll['StatusValue'].isin(years)]
fig = px.bar(opo, x="VendorValue",color="StatusValue", title="ANALYSIS")
fig.show()
# Out:
# <div>                            <div id="d547245c-80a2-4ee9-bd24-33ac24acbd0a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d547245c-80a2-4ee9-bd24-33ac24acbd0a")) {                    Plotly.newPlot(                        "d547245c-80a2-4ee9-bd24-33ac24acbd0a",                        [{"alignmentgroup":"True","hovertemplate":"StatusValue=Withdrawn<br>VendorValue=%{x}<br>count=%{y}<extra></extra>","legendgroup":"Withdrawn","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Withdrawn","offsetgroup":"Withdrawn","orientation":"v","showlegend":true,"textposition":"auto","type":"bar","x":["MSR COSMOS","EApps Tech LLC ","IDC Technologies Inc","Accuro Group","Accuro Group","Accuro Group","Accuro Group","Accuro Group","Accuro Group","Ajith","A
# ...

# %%
sd = pd.read_excel('BOOK.xlsx')
sd['Date Of Activity'] = pd.to_datetime(sd['Date Of Activity']) 
start_date= '2020-07-07'
end_date= '2021-07-07'
mask = (sd['Date Of Activity'] > start_date) & (sd['Date Of Activity']  <= end_date)
gh=sd.loc[mask]
fig = px.bar(gh, x="Recruiter",color="Status", title="ANALYSIS")
fig.show()
# ANALYSIS FROM "2020-JULY-07" TO "2021-JULY-07"
# Out:
# <div>                            <div id="7a265ad9-28c9-46ff-8123-2180e8d05650" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7a265ad9-28c9-46ff-8123-2180e8d05650")) {                    Plotly.newPlot(                        "7a265ad9-28c9-46ff-8123-2180e8d05650",                        [{"alignmentgroup":"True","hovertemplate":"Status=Position Confirmed<br>Recruiter=%{x}<br>count=%{y}<extra></extra>","legendgroup":"Position Confirmed","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Position Confirmed","offsetgroup":"Position Confirmed","orientation":"v","showlegend":true,"textposition":"auto","type":"bar","x":["Jaswanth Kandi","Jaswanth Kandi","Jaswanth Kandi","Jaswanth Kandi","Sharath K Rojanala","Zaheer H Syed","Zaheer H Syed","Spa
# ...

# %%
import plotly.express as px
fig = px.bar(gh, x="Vendor",color="Status", title="ANALYSIS")
fig.show()
# ANALYSIS FROM "2020-JULY-07" TO "2021-JULY-07"
# Out:
# <div>                            <div id="92e30928-7d0d-4bfd-a216-bff64181eb2b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("92e30928-7d0d-4bfd-a216-bff64181eb2b")) {                    Plotly.newPlot(                        "92e30928-7d0d-4bfd-a216-bff64181eb2b",                        [{"alignmentgroup":"True","hovertemplate":"Status=Position Confirmed<br>Vendor=%{x}<br>count=%{y}<extra></extra>","legendgroup":"Position Confirmed","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Position Confirmed","offsetgroup":"Position Confirmed","orientation":"v","showlegend":true,"textposition":"auto","type":"bar","x":["Peritus Inc","Net2Source Inc","IDC Technologies Inc","CA-One Tech Cloud Inc.","Accenture","Softcom Systems, Inc.","IDC Technolo
# ...

# %%
sd = pd.read_excel('TECHNOLOGY1.xlsx')
start_date= '2020-01-01'
end_date= '2021-07-07'
mask = (sd['Date Of Activity'] > start_date) & (sd['Date Of Activity']  <= end_date)
gu=sd.loc[mask]
years=["Rejected","Completed Interview","Awaiting Interview"]
bn=sd[sd['Status'].isin(years)]
ln=gu[gu['Status'].isin(years)]
pn=ln['Technology'].value_counts()
llx=pn.plot(kind='pie', figsize=(12,9), autopct='%1.2f',legend =True , label =False)

# %%
ppl  = pd.DataFrame(m).reset_index()
ppo = pd.DataFrame(n).reset_index()

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# Create subplots: use 'domain' type for Pie subplot
fig = make_subplots(rows=1, cols=2, specs=[[{'type':'domain'}, {'type':'domain'}]])
fig.add_trace(go.Pie(labels=ppo['index'], values=ppo['Technology']),
              1, 1)
fig.add_trace(go.Pie(labels=ppl['index'], values=ppl['Technology']),
              1, 2)

# Use `hole` to create a donut-like pie chart
fig.update_traces(hole=.4, hoverinfo="label+percent+name")

fig.update_layout(
    title_text="Bench Sale Analytics",
    # Add annotations in the center of the donut pies.
    annotations=[dict(text='2020-JAN-01:2021-JULY-07', x=0.18, y=0.5, font_size=6, showarrow=False),
                 dict(text='OVERALL TREND', x=0.82, y=0.5, font_size=10, showarrow=False)])
fig.show()
# Out:
# <div>                            <div id="9a7043df-800b-4b99-a3a1-1daf9f6ba5b4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9a7043df-800b-4b99-a3a1-1daf9f6ba5b4")) {                    Plotly.newPlot(                        "9a7043df-800b-4b99-a3a1-1daf9f6ba5b4",                        [{"domain":{"x":[0.0,0.45],"y":[0.0,1.0]},"hole":0.4,"hoverinfo":"label+percent+name","labels":["Java Developer","QA","DATA","Oracle","Functional Roles","DevOps Engineer","Hadoop Developer","VMWare","OTHERS","UI/UX Developer","Process Engineer"],"type":"pie","values":[88,80,25,17,14,8,7,7,4,3,1]},{"domain":{"x":[0.55,1.0],"y":[0.0,1.0]},"hole":0.4,"hoverinfo":"label+percent+name","labels":["Java Developer","QA","DATA","Oracle","Functional Roles","DevOps Engineer",
# ...

# %%
import cufflinks as cf

# Correct datatypes cufflinks does not support CategoryType so we make them strings and rebuild the dataframe. 
ppl  = pd.DataFrame(m).reset_index()
ppo = pd.DataFrame(n).reset_index()
ppl_pie = ppl.iplot(kind='pie', labels='index', values='Technology', title='OVERALL TREND')
ppo_pie = ppo.iplot(kind='pie', labels='index', values='Technology', title='ANALYSIS FROM 2020-JAN-01 TO 2021-JULY-07')

display(ppl_pie,ppo_pie)
# Out:
# <div>                            <div id="9cf3909d-6a48-4971-851d-29bf5d56173d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
m=bn['Technology'].value_counts()
n=ln['Technology'].value_counts()

# %%
y1=pd.DataFrame(m).reset_index()
y2=pd.DataFrame(n).reset_index()
result1=pd.concat([y1,y2],axis=1)

# %%
sd=pd.read_excel('TECHNOLOGY1.xlsx')
years=["Rejected","Completed Interview","Awaiting Interview"]
vv=sd[sd['Status'].isin(years)]
jj=vv.set_index('Follow-up')
ii=jj.loc['Follow-up #1']
ii1=jj.loc['Follow-up #2']
ii2=jj.loc['Follow-up #3']
xx=ii['Technology'].value_counts()
xx1=ii1['Technology'].value_counts()
xx2=ii2['Technology'].value_counts()
yy=pd.DataFrame(xx).reset_index()
yy1=pd.DataFrame(xx1).reset_index()
yy2=pd.DataFrame(xx2).reset_index()
result=pd.concat([xx,xx1,xx2],axis=1)

# %%
bb1=bn['Technology'].value_counts()
bb2=ln['Technology'].value_counts()

# %%
md
# Out:
#                      Technology  followup1  followup2  followup3
# 0                Java Developer         42         23         25
# 1                            QA         38         30         17
# 2                          DATA         11         11          9
# 3              Functional Roles          6          1          6
# 4               DevOps Engineer          4          2          1
# 5                        Oracle          4          2          9
# 6               UI/UX Developer          3          3          0
# 7                        VMWare          2          4          2
# 8              Hadoop Developer          2          0          4
# 9                        OTHERS          1          2          1
# 10             Process Engineer          1          0          0
# 11  Net Consultant (Full Stack)          0          1          0

# %%
md=pd.read_excel('followup.xlsx')
import plotly.express as px
fig = px.bar(md, x="Technology", y=["followup1","followup2","followup3"], title="followups of INTERVIEWS")
fig.show()
# Out:
# <div>                            <div id="0434ac08-a328-4de5-8c4b-db49ea66ed57" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0434ac08-a328-4de5-8c4b-db49ea66ed57")) {                    Plotly.newPlot(                        "0434ac08-a328-4de5-8c4b-db49ea66ed57",                        [{"alignmentgroup":"True","hovertemplate":"variable=followup1<br>Technology=%{x}<br>value=%{y}<extra></extra>","legendgroup":"followup1","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"followup1","offsetgroup":"followup1","orientation":"v","showlegend":true,"textposition":"auto","type":"bar","x":["Java Developer","QA","DATA","Functional Roles","DevOps Engineer","Oracle","UI/UX Developer","VMWare","Hadoop Developer","OTHERS","Process Engineer","Net Cons
# ...

# %%
ol=pd.read_excel('TEST.xlsx')
years=["Rejected","Completed Interview","Withdrawn","No Show","Closure","Position Confirmed"]
kn=sd[sd['Status'].isin(years)]
start_date= '2020-01-01'
end_date= '2021-07-07'
mask = (kn['Date Of Activity'] > start_date) & (kn['Date Of Activity']  <= end_date)
gp=kn.loc[mask]
follow=["Follow-up #1","Follow-up #2","Follow-up #3"]
mn=gp[gp['Follow-up'].isin(follow)]
nm=kn[kn['Follow-up'].isin(follow)]
pb=mn[["Status","Technology","Follow-up"]].value_counts()
pb1=nm[["Status","Technology","Follow-up"]].value_counts()

# %%
j1=pd.DataFrame(pb).reset_index()
j2=pd.DataFrame(pb1).reset_index()

result2=pd.concat([j1,j2],axis=1)

# %%
result2.to_excel('fileg.xlsx')

# %%
xc=pd.read_excel('fileg.xlsx')

# %%
pl=xc.set_index("Follow-up")
pl6=pl.loc["Follow-up #1"]
pl7=pl.loc["Follow-up #2"]
pl8=pl.loc["Follow-up #3"]

# %%
import plotly.express as px
fig = px.bar(ccx, x="Technology", y="Count", color="Follow-up",animation_frame="Status" ,barmode="group",title="ANALYSIS")
fig.show()
# Out:
# <div>                            <div id="e89d3ae3-1129-40bf-89b0-abd4a7774ca7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e89d3ae3-1129-40bf-89b0-abd4a7774ca7")) {                    Plotly.newPlot(                        "e89d3ae3-1129-40bf-89b0-abd4a7774ca7",                        [{"alignmentgroup":"True","hovertemplate":"Follow-up=Follow-up #3<br>Status=Withdrawn<br>Technology=%{x}<br>Count=%{y}<extra></extra>","legendgroup":"Follow-up #3","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Follow-up #3","offsetgroup":"Follow-up #3","orientation":"v","showlegend":true,"textposition":"auto","type":"bar","x":["DATA","DevOps Engineer","Functional Roles","Hadoop Developer","Java Developer","Oracle","OTHERS","Process Engineer","QA","Sh
# ...

# %%
ccx=pd.read_excel('fileg.xlsx')
